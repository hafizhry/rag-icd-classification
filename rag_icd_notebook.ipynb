# %% [markdown]
# # Import required packages

# %%
# !pip install langchain openai chromadb langchainhub pypdf tiktoken pymupdf PyPDF2 streamlit unstructured langchain-community
# Out:
# Collecting langchain
#   Using cached langchain-0.3.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting openai
#   Downloading openai-1.50.2-py3-none-any.whl.metadata (24 kB)
# Collecting chromadb
#   Downloading chromadb-0.5.11-py3-none-any.whl.metadata (6.8 kB)
# Collecting langchainhub
#   Downloading langchainhub-0.1.21-py3-none-any.whl.metadata (659 bytes)
# Collecting pypdf
#   Downloading pypdf-5.0.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting pymupdf
#   Downloading PyMuPDF-1.24.10-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting streamlit
#   Downloading streamlit-1.38.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting unstructured
#   Downloading unstructured-0.15.13-py3-none-any.whl.metadata (29 kB)
# Collecting langchain-community
#   Using cached langchain_community-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.6 (from langchain)
#   Using cached langchain_core-0.3.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Using cached langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Using cached langsmith-0.1.129-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.31.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.6.6-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.64.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.12.5)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting orjson>=3.9.12 (from chromadb)
#   Using cached orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (13.8.1)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (24.1)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub)
#   Downloading types_requests-2.32.0.20240914-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.9.11)
# Collecting PyMuPDFb==1.24.10 (from pymupdf)
#   Downloading PyMuPDFb-1.24.10-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.2-py3-none-manylinux2014_x86_64.whl.metadata (38 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.2.0)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.9.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.13.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting dataclasses-json (from unstructured)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 37.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.25.9-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.16.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.9.5)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Using cached pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured)
#   Using cached marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.7.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.6->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<=8.4.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (71.0.4)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.24.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (1.4.2)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: cryptography>=3.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (43.0.1)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured)
#   Downloading deepdiff-8.0.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Collecting mypy-extensions>=1.0.0 (from unstructured-client->unstructured)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.6.0)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Collecting orderly-set==5.2.2 (from deepdiff>=6.0->unstructured-client->unstructured)
#   Downloading orderly_set-5.2.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Using cached langchain-0.3.1-py3-none-any.whl (1.0 MB)
# Downloading openai-1.50.2-py3-none-any.whl (382 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.0/383.0 kB 25.3 MB/s eta 0:00:00
# Downloading chromadb-0.5.11-py3-none-any.whl (603 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.0/604.0 kB 37.8 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 64.1 MB/s eta 0:00:00
# Downloading langchainhub-0.1.21-py3-none-any.whl (5.2 kB)
# Downloading pypdf-5.0.1-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 21.7 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.6 MB/s eta 0:00:00
# Downloading PyMuPDF-1.24.10-cp310-none-manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 85.2 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.24.10-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 72.7 MB/s eta 0:00:00
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 17.8 MB/s eta 0:00:00
# Downloading streamlit-1.38.0-py2.py3-none-any.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 90.9 MB/s eta 0:00:00
# Downloading unstructured-0.15.13-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 68.1 MB/s eta 0:00:00
# Using cached langchain_community-0.3.1-py3-none-any.whl (2.4 MB)
# Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 18.4 MB/s eta 0:00:00
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading fastapi-0.115.0-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 6.3 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.2 MB/s eta 0:00:00
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 21.5 MB/s eta 0:00:00
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 60.7 MB/s eta 0:00:00
# Using cached langchain_core-0.3.7-py3-none-any.whl (400 kB)
# Using cached langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.129-py3-none-any.whl (292 kB)
# Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 7.2 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 80.1 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 4.6 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.8 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 12.9 MB/s eta 0:00:00
# Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 8.5 MB/s eta 0:00:00
# Using cached orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.6.6-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 3.6 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 73.5 MB/s eta 0:00:00
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading types_requests-2.32.0.20240914-py3-none-any.whl (15 kB)
# Downloading uvicorn-0.31.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.3 MB/s eta 0:00:00
# Downloading watchdog-4.0.2-py3-none-manylinux2014_x86_64.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 6.2 MB/s eta 0:00:00
# Downloading emoji-2.13.2-py3-none-any.whl (553 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.2/553.2 kB 30.8 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_iso639-2024.4.27-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 20.6 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.1-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 74.8 MB/s eta 0:00:00
# Downloading unstructured_client-0.25.9-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.9 MB/s eta 0:00:00
# Downloading deepdiff-8.0.1-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 6.6 MB/s eta 0:00:00
# Downloading orderly_set-5.2.2-py3-none-any.whl (11 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.5 MB/s eta 0:00:00
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 23.6 MB/s eta 0:00:00
# Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Using cached marshmallow-3.22.0-py3-none-any.whl (49 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.8 MB/s eta 0:00:00
# Downloading starlette-0.38.6-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.1 MB/s eta 0:00:00
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 79.8 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 25.2 MB/s eta 0:00:00
# Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 12.2 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.3 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.2 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.6 MB/s eta 0:00:00
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pypika, langdetect, durationpy
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=733603ac34a86394be809f31ff09f6dc7b4cb2e6a05795b248b249753ac7de68
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=fc9ad3b9cdcd02d1a4dd115e25728d2e0862e92af3badb1ff9733a0b9c538631
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for durationpy (setup.py) ... done
#   Created wheel for durationpy: filename=durationpy-0.7-py3-none-any.whl size=3462 sha256=02b23b0b5c2ad8d461fc28d84979f2f69ab1304b0b8ca1d25dea6b150907998c
#   Stored in directory: /root/.cache/pip/wheels/a2/52/58/701659d0f7467c85c273d8d06d8f74f2646ee7da4145ce77b5
# Successfully built pypika langdetect durationpy
# Installing collected packages: pypika, monotonic, filetype, durationpy, websockets, watchdog, uvloop, types-requests, tenacity, smmap, rapidfuzz, python-magic, python-iso639, python-dotenv, PyPDF2, pypdf, PyMuPDFb, overrides, orjson, orderly-set, opentelemetry-util-http, opentelemetry-proto, olefile, mypy-extensions, mmh3, marshmallow, langdetect, jsonpointer, jsonpath-python, jiter, importlib-metadata, humanfriendly, httptools, h11, emoji, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, typing-inspect, tiktoken, starlette, requests-toolbelt, python-oxmsg, pymupdf, pydeck, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, langchainhub, jsonpatch, httpcore, gitdb, deepdiff, coloredlogs, pydantic-settings, opentelemetry-semantic-conventions, opentelemetry-instrumentation, onnxruntime, kubernetes, httpx, gitpython, fastapi, dataclasses-json, unstructured-client, opentelemetry-sdk, opentelemetry-instrumentation-asgi, openai, langsmith, unstructured, streamlit, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langchain-core, langchain-text-splitters, chromadb, langchain, langchain-community
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
# Successfully installed PyMuPDFb-1.24.10 PyPDF2-3.0.1 asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 chroma-hnswlib-0.7.6 chromadb-0.5.11 coloredlogs-15.0.1 dataclasses-json-0.6.7 deepdiff-8.0.1 deprecated-1.2.14 durationpy-0.7 emoji-2.13.2 fastapi-0.115.0 filetype-1.2.0 gitdb-4.0.11 gitpython-3.1.43 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.2 humanfriendly-10.0 importlib-metadata-8.4.0 jiter-0.5.0 jsonpatch-1.33 jsonpath-python-1.0.6 jsonpointer-3.0.0 kubernetes-31.0.0 langchain-0.3.1 langchain-community-0.3.1 langchain-core-0.3.7 langchain-text-splitters-0.3.0 langchainhub-0.1.21 langdetect-1.0.9 langsmith-0.1.129 marshmallow-3.22.0 mmh3-5.0.1 monotonic-1.6 mypy-extensions-1.0.0 olefile-0.47 onnxruntime-1.19.2 openai-1.50.2 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 orderly-set-5.2.2 orjson-3.10.7 overrides-7.7.0 posthog-3.6.6 pydantic-settings-2.5.2 pydeck-0.9.1 pymupdf-1.24.10 pypdf-5.0.1 pypika-0.48.9 python-dotenv-1.0.1 python-iso639-2024.4.27 python-magic-0.4.27 python-oxmsg-0.0.1 rapidfuzz-3.10.0 requests-toolbelt-1.0.0 smmap-5.0.1 starlette-0.38.6 streamlit-1.38.0 tenacity-8.5.0 tiktoken-0.7.0 types-requests-2.32.0.20240914 typing-inspect-0.9.0 unstructured-0.15.13 unstructured-client-0.25.9 uvicorn-0.31.0 uvloop-0.20.0 watchdog-4.0.2 watchfiles-0.24.0 websockets-13.1

# %%
import os
from dotenv import load_dotenv
import openai
from openai import OpenAI
import pandas as pd
import warnings
import langchain
import argparse
from dataclasses import dataclass
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
from transformers import AutoTokenizer, pipeline
from langchain import HuggingFacePipeline
from langchain.chains import RetrievalQA
from langchain.document_loaders import DirectoryLoader
from google.colab import userdata
from langchain import hub
from langchain.schema.runnable import RunnablePassthrough


# Suppress FutureWarning messages
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Load GPT

# %%
from google.colab import userdata

with open('/content/.env', 'w') as file:
    gpt_key = userdata.get('gpt_key')
    if gpt_key:
        file.write(f"OPENAI_API_KEY={gpt_key}\n")
    else:
        print("gpt_key not found in userdata.")

# Load the environment variables from the .env file
load_dotenv('/content/.env')

# Access the OpenAI API key and org id
api_key = os.getenv('OPENAI_API_KEY')
org_id = userdata.get('org_id')

if org_id and api_key:
    client = OpenAI(api_key=api_key, organization=org_id)
    print(f"OpenAI client initialized with org_id: {org_id}")
else:
    print("Failed to initialize OpenAI client. Check org_id and API key.")
# Out:
# OpenAI client initialized with org_id: org-sD1mhBLcKZViamsY2rWXNqzB

# %% [markdown]
# # Load Dataset

# %%
def excel_to_markdown(file_path):
    # Load the Excel file
    xls = pd.ExcelFile(file_path, engine='openpyxl')

    # Markdown string to hold all sheets data
    all_sheets_markdown = ""

    # Process each sheet
    for sheet_name in xls.sheet_names:
        df = pd.read_excel(xls, sheet_name=sheet_name)

        # Convert DataFrame to Markdown
        markdown = df.to_markdown(index=False)

        # Add a header for the sheet and append the Markdown
        all_sheets_markdown += f"## {sheet_name}\n{markdown}\n\n"

    return all_sheets_markdown

# %%
# Specify the path to your Excel file
markdown_output = excel_to_markdown("/content/Tabel-ICD-10-English-Indonesia-Lengkap.xlsx") # Please adjust this path to the location of your Excel file

# Print or save the Markdown output
print(markdown_output)

# Save to a file
with open("output.md", "w") as file:
    file.write(markdown_output)
# Out:
# ## GOL A
# | Category   |   Subcategory | English_name                                                     | Indonesian_name                                                                |
# |:-----------|--------------:|:-----------------------------------------------------------------|:-------------------------------------------------------------------------------|
# | A00        |           nan | Cholera                                                          | Kolera                                                                         |
# | A00        |             0 | Cholera due to Vibrio cholerae 01, biovar cholerae               | Kolera yang disebabkan oleh Vibrio cholerae 01, biovar cholerae                |
# | A00        |             1 | Cholera due to Vibrio cholerae 01, biovar el tor                 | Kolera yang disebabkan oleh Vibrio cholerae 01, biovar el tor                  |
# | A00        |             9 | Cholera, unspecified                                             | Kolera, tidak terspesifikasi                                                   |
# | A01        |           nan | Typhoid and paratyphoid fevers                                   | Demam tifoid dan paratifoid                                                    |
# | A01        |             0 | Typhoid fever                                                    | Demam tifoid                                                                   |
# | A01        |             1 | Paratyphoid fever A                                              | Demam paratifoid A                                                             |
# | A01        |             2 | Paratyphoid fever B                                              | Demam paratifoid B                                                             |
# | A01        |             3 | Paratyphoid fever C                                              | Demam paratifoid C                                                             |
# | A01        |             4 | Paratyphoid fever, unspecified                                   | Demam paratifoid, tidak terspesifikasi                                         |
# | A02        |           nan | Other salmonella infections                                      | Infeksi salmonella lainnya                                                     |
# | A02        |             0 | Salmonella gastroenteritis                                       | Salmonella gastroenteritis                                                     |
# | A02        |             1 | Salmonella septicemia                                            | Salmonella septikemia                                                          |
# | A02        |             2 | Localized salmonella infections                                  | Infeksi salmonella lokal                                                       |
# | A02        |             8 | Other specified salmonella infections                            | Infeksi salmonella spesifik lainnya                                            |
# | A02        |             9 | Salmonella infection, unspecified                                | Infeksi salmonella, tidak terspesifikasi                                       |
# | A03        |           nan | Shigellosis                                                      | Shigellosis                                                                    |
# | A03        |             0 | Shigellosis due to Shigella dysenteriae                          | Shigellosis yang disebabkan oleh Shigella dysentriae                           |
# | A03        |             1 | Shigellosis due to Shigella flexneri                             | Shigellosis yang disebabkan oleh Shigella flexneri                             |
# | A03        |             2 | Shigellosis due to Shigella boydii                               | Shigellosis yang disebabkan oleh Shigella boydii                               |
# | A03        |             3 | Shigellosis due to Shigella sonnei                               | Shigellosis yang disebabkan oleh Shigella sonnei                               |
# | A03        |             8 | Other shigellosis                                                | Shigellosis lainnya                                                            |
# | A03        |             9 | Shigellosis, unspecified                                         | Shigellosis, tidak terspesifikasi                                              |
# | A04        |           nan | Other bacterial intestinal infections                            | Infeksi bakteri usus lainnya                                                   |
# | A04        |             0 | Enteropathogenic Escherichia coli infection                      | Infeksi Escherichia coli enteropatogenik                                       |
# | A04        |             1 | Enterotoxigenic Escherichia coli infection                       | Infeksi Escherichia coli enterotoksigenik                                      |
# | A04        |             2 | Enteroinvasive Escherichia coli infection                        | Infeksi Escherichia coli enteroinvasif                                         |
# | A04        |             3 | Enterohemorrhagic Escherichia coli infection                     | Infeksi Escherichia coli enterohemoragik                                       |
# | A04        |             4 | Other intestinal Escherichia coli infections                     | Infeksi Escherichia coli lain                                                  |
# | A04        |             5 | Campylobacter enteritis                                          | Kampilobakter enteritis                                                        |
# | A04        |             6 | Enteritis due to Yersinia enterocolitica                         | Enteritis yang disebabkan oleh Yersinia enterocolitica                         |
# | A04        |             7 | Enterocolitis due to Clostridium difficile                       | Enterokolitis yang disebabkan oleh Clostridium difficile                       |
# | A04        |             8 | Other specified bacterial intestinal infections                  | Infeksi bakteri usus spesifik lainnya                                          |
# | A04        |             9 | Bacterial intestinal infection, unspecified                      | Infeksi bakteri usus, tidak terspesifikasi                                     |
# | A05        |           nan | Other bacterial food-borne intoxications                         | Intoksikasi (keracunan) bakteri (yang ditularkan lewat) makanan lainnya        |
# | A05        |             0 | Food-borne staphylococcal intoxication                           | Intoksikasi (keracunan) stafilokokus melalui makanan                           |
# | A05        |             1 | Botulism                                                         | Botulism                                                                       |
# | A05        |             2 | Food-borne Clostridium perfringens [Clostridium welchii] intox   | Intoksikasi (keracunan) Clostridium perfringens [Clostridium welchii] mela     |
# | A05        |             3 | Food-borne Vibrio parahemolyticus intoxication                   | Intoksikasi (keracunan) Vibrio parahemolyticus melalui makanan                 |
# | A05        |             4 | Food-borne Bacillus cereus intoxication                          | Intoksikasi (keracunan) Bacillus cereus melalui makanan                        |
# | A05        |             8 | Other specified bacterial food-borne intoxications               | Intoksikasi (keracunan) bakteri spesifik lainnya melalui makanan               |
# | A05        |             9 | Bacterial food-borne intoxication, unspecified                   | Intoksikasi (keracunan) bakteri melalui makanan, tidak terspesifikasi          |
# | A06        |           nan | Amoebiasis                                                       | Amubiasis                                                                      |
# | A06        |             0 | Acute amebic dysentery                                           | Disenteri amuba akut                                                           |
# | A06        |             1 | Chronic intestinal amebiasis                                     | Amebiasis (amubiasis) usus kronik                                              |
# | A06        |             2 | Amebic nondysenteric colitis                                     | Kolitis nondisenteri amuba                                                     |
# | A06        |             3 | Ameboma of intestine                                             | Ameboma usus                                                                   |
# | A06        |             4 | Amebic liver abscess                                             | Abses hati yang disebabkan oleh amuba                                          |
# | A06        |             5 | Amebic lung abscess                                              | Abses paru yang disebabkan oleh amuba                                          |
# | A06        |             6 | Amebic brain abscess                                             | Abses otak yang disebabkan oleh amuba                                          |
# | A06        |             7 | Cutaneous amebiasis                                              | Amebiasis (amubiasis) kulit                                                    |
# | A06        |             8 | Amebic infection of other sites                                  | Infeksi amuba di tempat lain                                                   |
# | A06        |             9 | Amebiasis, unspecified                                           | Amebiasis (amubiasis), tidak terspesifikasi                                    |
# | A07        |           nan | Other protozoal intestinal diseases                              | Penyakit protozoa usus lainnya                                                 |
# | A07        |             0 | Balantidiasis                                                    | Balantidiasis                                                                  |
# | A07        |             1 | Giardiasis [lambliasis]                                          | Giardiasis [lambliasis]                                                        |
# | A07        |             2 | Cryptosporidiosis                                                | Kriptosporidiosis                                                              |
# | A07        |             3 | Isosporiasis                                                     | Isosporiasis                                                                   |
# | A07        |             8 | Other specified protozoal intestinal diseases                    | Penyakit pada usus yang disebabkan oleh protozoa spesifik lainnya              |
# | A07        |             9 | Protozoal intestinal disease, unspecified                        | Penyakit pada usus yang disebabkan oleh protozoa, tidak terspesifikasi         |
# | A08        |           nan | Viral and other specified intestinal infections                  | Infeksi virus dan infeksi spesifik lainnya pada usus                           |
# | A08        |             0 | Rotaviral enteritis                                              | Enteritis rotavirus                                                            |
# | A08        |             1 | Acute gastroenteropathy due to Norwalk agent                     | Gastroenteropati akut yang disebabkan oleh agen Norwalk                        |
# | A08        |             2 | Adenoviral enteritis                                             | Enteritis Adenovirus                                                           |
# | A08        |             3 | Other viral enteritis                                            | Enteritis virus lainnya                                                        |
# | A08        |             4 | Viral intestinal infection, unspecified                          | Infeksi usus yang disebabkan oleh virus tidak terspesifikasi                   |
# | A08        |             5 | Other specified intestinal infections                            | Infeksi usus spesifik lainnya                                                  |
# | A09        |           nan | Diarrhea and gastroenteritis of presumed infectious origin       | Diare dan gastroenteritis yang diduga disebabkan oleh infeksi                  |
# | A16        |           nan | Respiratory tuberculosis, not confirmed bacteriologically or his | Tuberkulosis pernafasan yang tidak dikonfirmasi secara bakteriologis ata       |
# | A16        |             2 | Tuberculosis of lung, without mention of bacteriological or hist | Tuberkulosis pada paru tanpa menyebutkan konfirmasi bakteriologis ata          |
# | A16        |             3 | Tuberculosis of intrathoracic lymph nodes, without mention of    | Tuberkulosis nodus limfatikus dalam dadatanpa menyebutkan konfirma             |
# | A16        |             4 | Tuberculosis of larynx, trachea, and bronchus, without mentio    | Tuberkulosis pada laring                                                       |
# | A16        |             5 | Tuberculous pleurisy, without mention of bacteriological or his  | Tuberkulous pleura                                                             |
# | A16        |             7 | Primary respiratory tuberculosis, without mention of bacteriolo  | Tuberkulosis pernafasan primer tanpa menyebutkan konfirmasi bakteriolo         |
# | A16        |             8 | Other respiratory tuberculosis, without mention of bacteriologic | Tuberkulosis pernafasan lain                                                   |
# | A16        |             9 | Respiratory tuberculosis unspecified, without mention of bacte   | Tuberkulosis pernafasan tidak terspesifikasi                                   |
# | A17        |           nan | Tuberculosis of nervous system                                   | Tuberkulosis pada sistem saraf                                                 |
# | A17        |             0 | Tuberculous meningitis                                           | Tuberkulous meningitis                                                         |
# | A17        |             1 | Meningeal tuberculoma                                            | Tuberkuloma pada mening (selaput otak)                                         |
# | A17        |             8 | Other tuberculosis of nervous system                             | Tuberkulosis lain pada sistem saraf                                            |
# | A17        |             9 | Tuberculosis of nervous system, unspecified                      | Tuberkulosis pada sistem saraf                                                 |
# | A18        |           nan | Tuberculosis of other organs                                     | Tuberkulosis pada organ-organ lain                                             |
# | A18        |             0 | Tuberculosis of bones and joints                                 | Tuberkulosis pada tulang dan sendi                                             |
# | A18        |             1 | Tuberculosis of genitourinary system                             | Tuberkulosis pada sistem genital-kemih                                         |
# | A18        |             2 | Tuberculous peripheral lymphadenopathy                           | Tuberkulous limfadenopati perifer                                              |
# | A18        |             3 | Tuberculosis of intestines, peritoneum, and mesenteric glands    | Tuberkulosis pada usus                                                         |
# | A18        |             4 | Tuberculosis of skin and subcutaneous tissue                     | Tuberkulosis pada kulit dan jaringan subkutan                                  |
# | A18        |             5 | Tuberculosis of eye                                              | Tuberkulosis pada mata                                                         |
# | A18        |             6 | Tuberculosis of ear                                              | Tuberkulosis pada telinga                                                      |
# | A18        |             7 | Tuberculosis of adrenal glands                                   | Tuberkulosis pada kelenjar adrenal                                             |
# | A18        |             8 | Tuberculosis of other specified organs                           | Tuberkulosis organ-organ spesifik lainnya                                      |
# | A19        |           nan | Miliary tuberculosis                                             | Tuberkulosis miliar                                                            |
# | A19        |             0 | Acute miliary tuberculosis of a single specified site            | Tuberkulosis miliar akut pada satu lokasi khusus                               |
# | A19        |             1 | Acute miliary tuberculosis of multiple sites                     | Tuberkulosis miliar akut pada banyak tempat                                    |
# | A19        |             2 | Acute miliary tuberculosis, unspecified                          | Tuberkulosis miliar akut, tidak terspesifikasi                                 |
# | A19        |             8 | Other miliary tuberculosis                                       | Tuberkulosis miliar lainnya                                                    |
# | A19        |             9 | Miliary tuberculosis, unspecified                                | Tuberkulosis miliar, tidak terspesifikasi                                      |
# | A20        |           nan | Plague                                                           | Pes                                                                            |
# | A20        |             0 | Bubonic plague                                                   | Pes dengan bubo                                                                |
# | A20        |             1 | Cellulocutaneous plague                                          | Pes jenis selulokutan                                                          |
# | A20        |             2 | Pneumonic plague                                                 | Pes yang menyerang paru                                                        |
# | A20        |             3 | Plague meningitis                                                | Pes yang mengakibatkan meningitis                                              |
# | A20        |             7 | Septicemic plague                                                | Pes septikemi                                                                  |
# | A20        |             8 | Other forms of plague                                            | Bentuk-bentuk lain dari pes                                                    |
# | A20        |             9 | Plague, unspecified                                              | Pes, tidak terspesifikasi                                                      |
# | A21        |           nan | Tularemia                                                        | Tularemia                                                                      |
# | A21        |             0 | Ulceroglandular tularemia                                        | Tularemia jenis ulseroglandula                                                 |
# | A21        |             1 | Oculoglandular tularemia                                         | Tularemia jenis okuloglandula                                                  |
# | A21        |             2 | Pulmonary tularemia                                              | Tularemia paru                                                                 |
# | A21        |             3 | Gastrointestinal tularemia                                       | Tularemia lambung dan usus                                                     |
# | A21        |             7 | Generalized tularemia                                            | Tularemia general                                                              |
# | A21        |             8 | Other forms of tularemia                                         | Bentuk-bentuk lain dari tularemia                                              |
# | A21        |             9 | Tularemia, unspecified                                           | Tularemia, tidak terspesifikasi                                                |
# | A22        |           nan | Anthrax                                                          | Antraks                                                                        |
# | A22        |             0 | Cutaneous anthrax                                                | Antraks yang menyerang kulit                                                   |
# | A22        |             1 | Pulmonary anthrax                                                | Antraks yang menyerang paru                                                    |
# | A22        |             2 | Gastrointestinal anthrax                                         | Antraks yang menyerang lambung dan usus                                        |
# | A22        |             7 | Anthrax septicemia                                               | Antraks septikemia                                                             |
# | A22        |             8 | Other forms of anthrax                                           | Bentuk-bentuk lain dari antraks                                                |
# | A22        |             9 | Anthrax, unspecified                                             | Antraks, tidak terspesifikasi                                                  |
# | A23        |           nan | Brucellosis                                                      | Brusellosis                                                                    |
# | A23        |             0 | Brucellosis due to Brucella melitensis                           | Brusellosis yang disebabkan oleh Brucella melitensis                           |
# | A23        |             1 | Brucellosis due to Brucella abortus                              | Brusellosis yang disebabkan oleh Brucella abortus                              |
# | A23        |             2 | Brucellosis due to Brucella suis                                 | Brusellosis yang disebabkan oleh Brucella suis                                 |
# | A23        |             3 | Brucellosis due to Brucella canis                                | Brusellosis yang disebabkan oleh Brucella canis                                |
# | A23        |             8 | Other brucellosis                                                | Brusellosis lainnya                                                            |
# | A23        |             9 | Brucellosis, unspecified                                         | Brusellosis, tidak terspesifikasi                                              |
# | A24        |           nan | Glanders and melioidosis                                         | Glanders dan melioidosis                                                       |
# | A24        |             0 | Glanders                                                         | Glanders                                                                       |
# | A24        |             1 | Acute and fulminating melioidosis                                | Melioidosis akut dan fulminan                                                  |
# | A24        |             2 | Subacute and chronic melioidosis                                 | Melioidosis subakut dan kronik                                                 |
# | A24        |             3 | Other melioidosis                                                | Melioidosis lainnya                                                            |
# | A24        |             4 | Melioidosis, unspecified                                         | Melioidosis, tidak terspesifikasi                                              |
# | A25        |           nan | Rat-bite fevers                                                  | Demam akibat gigitan tikus (rat)                                               |
# | A25        |             0 | Spirillosis                                                      | Spirillosis                                                                    |
# | A25        |             1 | Streptobacillosis                                                | Streptobasillosis                                                              |
# | A25        |             9 | Rat-bite fever, unspecified                                      | Demam akibat gigitan tikus (rat), tidak terspesifikasi                         |
# | A26        |           nan | Erysipeloid                                                      | Erisipeloid                                                                    |
# | A26        |             0 | Cutaneous erysipeloid                                            | Erisipeloid pada kulit                                                         |
# | A26        |             7 | Erysipelothrix septicemia                                        | Erisipelotriks septikemia                                                      |
# | A26        |             8 | Other forms of erysipeloid                                       | Bentuk-bentuk lain dari erisipeloid                                            |
# | A26        |             9 | Erysipeloid, unspecified                                         | Erisipeloid, tidak terspesifikasi                                              |
# | A27        |           nan | Leptospirosis                                                    | Leptospirosis                                                                  |
# | A27        |             0 | Leptospirosis icterohemorrhagica                                 | Leptospirosis icterohemorrhagica                                               |
# | A27        |             8 | Other forms of leptospirosis                                     | Bentuk-bentuk lain dari leptospirosis                                          |
# | A27        |             9 | Leptospirosis, unspecified                                       | Leptospirosis, tidak terspesifikasi                                            |
# | A28        |           nan | Other zoonotic bacterial diseases, not elsewhere classified      | Penyakit bakterial lain yang ditularkan melalui hewan, tidak terklasifikasi d  |
# | A28        |             0 | Pasteurellosis                                                   | Pasteurellosis                                                                 |
# | A28        |             1 | Cat-scratch disease                                              | Penyakit cakaran kucing                                                        |
# | A28        |             2 | Extraintestinal yersiniosis                                      | Yersiniosis diluar usus                                                        |
# | A28        |             8 | Other specified zoonotic bacterial diseases, not elsewhere cla   | Penyakit bakterial spesifik lain yang ditularkan melalui hewan, tidak terkla   |
# | A28        |             9 | Zoonotic bacterial disease, unspecified                          | Penyakit bakterial yang ditularkan melalui hewan, tidak terspesifikasi         |
# | A30        |           nan | Leprosy [Hansen's disease]                                       | Lepra [Penyakit Hansen]                                                        |
# | A30        |             0 | Indeterminate leprosy                                            | ? Lepra yang tidak dapat ditetapkan                                            |
# | A30        |             1 | Tuberculoid leprosy                                              | Lepra tuberkuloid                                                              |
# | A30        |             2 | Borderline tuberculoid leprosy                                   | Lepra tuberkuloid borderline                                                   |
# | A30        |             3 | Borderline leprosy                                               | Lepra borderline                                                               |
# | A30        |             4 | Borderline lepromatous leprosy                                   | Lepra lepromatosa borderline                                                   |
# | A30        |             5 | Lepromatous leprosy                                              | Lepra lepromatosa                                                              |
# | A30        |             8 | Other forms of leprosy                                           | Bentuk-bentuk lain dari lepra                                                  |
# | A30        |             9 | Leprosy, unspecified                                             | Lepra, tidak terspesifikasi                                                    |
# | A31        |           nan | Infection due to other mycobacteria                              | Infeksi karena mikobakteria lainnya                                            |
# | A31        |             0 | Pulmonary mycobacterial infection                                | Infeksi mikobakter pada paru                                                   |
# | A31        |             1 | Cutaneous mycobacterial infection                                | Infeksi mikobakter pada kulit                                                  |
# | A31        |             8 | Other mycobacterial infections                                   | Infeksi mikobakter lainnya                                                     |
# | A31        |             9 | Mycobacterial infection, unspecified                             | Infeksi mikobakter, tidak terspesifikasi                                       |
# | A32        |           nan | Listeriosis                                                      | Listeriosis                                                                    |
# | A32        |             0 | Cutaneous listeriosis                                            | Listeriosis kulit                                                              |
# | A32        |             1 | Listerial meningitis and meningoencephalitis                     | Listeria meningitis dan meningoensefalitis                                     |
# | A32        |             7 | Listerial septicemia                                             | Listeria septikemi                                                             |
# | A32        |             8 | Other forms of listeriosis                                       | Bentuk-bentuk lain dari listeriosis                                            |
# | A32        |             9 | Listeriosis, unspecified                                         | Listeriosis, tidak terspesifikasi                                              |
# | A33        |           nan | Tetanus neonatorum                                               | Tetanus neonatorum                                                             |
# | A34        |           nan | Obstetrical tetanus                                              | Tetanus yang terkait dengan kebidanan                                          |
# | A35        |           nan | Other tetanus                                                    | Tetanus lainnya                                                                |
# | A36        |           nan | Diphtheria                                                       | Difteria                                                                       |
# | A36        |             0 | Pharyngeal diphtheria                                            | Difteria faring                                                                |
# | A36        |             1 | Nasopharyngeal diphtheria                                        | Difteria nasofaring                                                            |
# | A36        |             2 | Laryngeal diphtheria                                             | Difteria laring                                                                |
# | A36        |             3 | Cutaneous diphtheria                                             | Difteria kulit                                                                 |
# | A36        |             8 | Other diphtheria                                                 | Difteria lainnya                                                               |
# | A36        |             9 | Diphtheria, unspecified                                          | Difteria, tidak terspesifikasi                                                 |
# | A37        |           nan | Whooping cough                                                   | Batuk rejan                                                                    |
# | A37        |             0 | Whooping cough due to Bordetella pertussis                       | Batuk rejan yang disebabkan oleh Bordatella pertussis                          |
# | A37        |             1 | Whooping cough due to Bordetella parapertussis                   | Batuk rejan yang disebabkan oleh Bordatella parapertusis                       |
# | A37        |             8 | Whooping cough due to other Bordetella species                   | Batuk rejan yang disebabkan oleh Bordatella species                            |
# | A37        |             9 | Whooping cough, unspecified                                      | Batuk rejan, tidak terspesifikasi                                              |
# | A38        |           nan | Scarlet fever                                                    | Demam skarlet                                                                  |
# | A39        |           nan | Meningococcal infection                                          | Infeksi meningokokus                                                           |
# | A39        |             0 | Meningococcal meningitis                                         | Meningitis meningokokus                                                        |
# | A39        |             1 | Waterhouse-Friderichsen syndrome                                 | Sindrom Waterhouse-Friderichsen                                                |
# | A39        |             2 | Acute meningococcemia                                            | Meningokoksemia akut                                                           |
# | A39        |             3 | Chronic meningococcemia                                          | Meningokoksemia kronik                                                         |
# | A39        |             4 | Meningococcemia, unspecified                                     | Meningokoksemia, tidak terspesifikasi                                          |
# | A39        |             5 | Meningococcal heart disease                                      | Penyakit jantung akibat meningokokus                                           |
# | A39        |             8 | Other meningococcal infections                                   | Infeksi meningokokus lainnya                                                   |
# | A39        |             9 | Meningococcal infection, unspecified                             | Infeksi meningokokus, tidak terspesifikasi                                     |
# | A40        |           nan | Streptococcal septicemia                                         | Septikemia yang disebabkan oleh streptokokus                                   |
# | A40        |             0 | Septicemia due to streptococcus, group A                         | Septikemia yang disebabkan oleh Streptokokus, grup A                           |
# | A40        |             1 | Septicemia due to streptococcus, group B                         | Septikemia yang disebabkan oleh Streptokokus, grup B                           |
# | A40        |             2 | Septicemia due to streptococcus, group D                         | Septikemia yang disebabkan oleh Streptokokus, grup D                           |
# | A40        |             3 | Septicemia due to Streptococcus pneumoniae                       | Septikemia yang disebabkan oleh Streptokokus pneumoniae                        |
# | A40        |             8 | Other streptococcal septicemia                                   | Septikemia yang disebabkan oleh Streptokokus lainnya                           |
# | A40        |             9 | Streptococcal septicemia, unspecified                            | Septikemi yang disebabkan oleh streptokokus, tidak terspesifikasi              |
# | A41        |           nan | Other septicemia                                                 | Septikemia lainnya                                                             |
# | A41        |             0 | Septicemia due to Staphylococcus aureus                          | Septikemi yang disebabkan oleh Stafilokokus aureus                             |
# | A41        |             1 | Septicemia due to other specified staphylococcus                 | Septikemi yang disebabkan oleh stafilokokus spesifik lainnya                   |
# | A41        |             2 | Septicemia due to unspecified staphylococcus                     | Septikemi yang disebabkan oleh stafilokokus tidak terspesifikasi               |
# | A41        |             3 | Septicemia due to Hemophilus influenzae                          | Septikemia yang disebabkan oleh Hemofilus influenzae                           |
# | A41        |             4 | Septicemia due to anaerobes                                      | Septikemia yang disebabkan oleh organisme anaerob                              |
# | A41        |             5 | Septicemia due to other Gram-negative organisms                  | Septikemia yang disebabkan oleh organisme Gram-negatif lainnya                 |
# | A41        |             8 | Other specified septicemia                                       | Septikemia spesifik lainnya                                                    |
# | A41        |             9 | Septicemia, unspecified                                          | Septikemia, tidak terspesifikasi                                               |
# | A42        |           nan | Actinomycosis                                                    | Aktinomikosis                                                                  |
# | A42        |             0 | Pulmonary actinomycosis                                          | Aktinomikosis paru                                                             |
# | A42        |             1 | Abdominal actinomycosis                                          | Aktinomikosis perut                                                            |
# | A42        |             2 | Cervicofacial actinomycosis                                      | Aktinomikosis leher dan wajah                                                  |
# | A42        |             7 | Actinomycotic septicemia                                         | Septikemia yang disebabkan oleh aktinomikotik                                  |
# | A42        |             8 | Other forms of actinomycosis                                     | Bentuk-bentuk lain dari aktinomikosis                                          |
# | A42        |             9 | Actinomycosis, unspecified                                       | Aktinomikosis, tidak terspesifikasi                                            |
# | A43        |           nan | Nocardiosis                                                      | Nokardiosis                                                                    |
# | A43        |             0 | Pulmonary nocardiosis                                            | Nokardiosis paru                                                               |
# | A43        |             1 | Cutaneous nocardiosis                                            | Nokardiosis kulit                                                              |
# | A43        |             8 | Other forms of nocardiosis                                       | Bentuk-bentuk lain dari nokardiosis                                            |
# | A43        |             9 | Nocardiosis, unspecified                                         | Nokardiosis, tidak terspesifikasi                                              |
# | A44        |           nan | Bartonellosis                                                    | Bartonellosis                                                                  |
# | A44        |             0 | Systemic bartonellosis                                           | Bartonellosis sistemik                                                         |
# | A44        |             1 | Cutaneous and mucocutaneous bartonellosis                        | Bartonellosis kulit dan mukosa-kulit                                           |
# | A44        |             8 | Other forms of bartonellosis                                     | Bentuk-bentuk lain dari bartonellosis                                          |
# | A44        |             9 | Bartonellosis, unspecified                                       | Bartonellosis, tidak terspesifikasi                                            |
# | A46        |           nan | Erysipelas                                                       | Erisipelas                                                                     |
# | A48        |           nan | Other bacterial diseases, not elsewhere classified               | Penyakit-penyakit yang disebabkan oleh bakteri lainnya, tidak terklasifika     |
# | A48        |             0 | Gas gangrene                                                     | Gas gangren                                                                    |
# | A48        |             1 | Legionnaires' disease                                            | Penyakit Legionnaires'                                                         |
# | A48        |             2 | Nonpneumonic Legionnaires' disease [Pontiac fever]               | Penyakit Legionnaires' non paru [Demam Pontiac]                                |
# | A48        |             3 | Toxic shock syndrome                                             | Sindrom syok toksik                                                            |
# | A48        |             4 | Brazilian purpuric fever                                         | Demam purpura Brazil                                                           |
# | A48        |             8 | Other specified bacterial diseases                               | Penyakit-penyakit yang disebabkan oleh bakteri spesifik lainnya                |
# | A49        |           nan | Bacterial infection of unspecified site                          | Infeksi yang disebabkan oleh bakteri pada tempat yang tidak terspesifika       |
# | A49        |             0 | Staphylococcal infection, unspecified                            | Infeksi stafilokokus, tidak terspesifikasi                                     |
# | A49        |             1 | Streptococcal infection, unspecified                             | Infeksi streptokokus, tidak terspesifikasi                                     |
# | A49        |             2 | Hemophilus influenzae infection, unspecified                     | Infeksi Hemofilus influenzae, tidak terspesifikasi                             |
# | A49        |             3 | Mycoplasma infection, unspecified                                | Infeksi mikoplasma, tidak terspesifikasi                                       |
# | A49        |             8 | Other bacterial infections of unspecified site                   | Infeksi yang disebabkan oleh bakteri lainnya pada tempat yang tidak ters       |
# | A49        |             9 | Bacterial infection, unspecified                                 | Infeksi yang disebabkan oleh bakteri, tidak terspesifikasi                     |
# | A50        |           nan | Congenital syphilis                                              | Sifilis kongenital                                                             |
# | A50        |             0 | Early congenital syphilis, symptomatic                           | Sifilis kongenital dini, simptomatik                                           |
# | A50        |             1 | Early congenital syphilis, latent                                | Sifilis kongenital dini, latent                                                |
# | A50        |             2 | Early congenital syphilis, unspecified                           | Sifilis kongenital dini, tidak terspesifikasi                                  |
# | A50        |             3 | Late congenital syphilitic oculopathy                            | Sifilis kongenital lanjut okulopati                                            |
# | A50        |             4 | Late congenital neurosyphilis [juvenile neurosyphilis]           | Neurosifilis kongenital lanjut [juvenile neurosifilis]                         |
# | A50        |             5 | Other late congenital syphilis, symptomatic                      | Sifilis kongenital lanjut lainnya, simptomatik                                 |
# | A50        |             6 | Late congenital syphilis, latent                                 | Sifilis kongenital lanjut, latent                                              |
# | A50        |             7 | Late congenital syphilis, unspecified                            | Sifilis kongenital lanjut, tidak terspesifikasi                                |
# | A50        |             9 | Congenital syphilis, unspecified                                 | Sifilis kongenital, tidak terspesifikasi                                       |
# | A51        |           nan | Early syphilis                                                   | Sifilis dini                                                                   |
# | A51        |             0 | Primary genital syphilis                                         | Sifilis genital primer                                                         |
# | A51        |             1 | Primary anal syphilis                                            | Sifilis anal primer                                                            |
# | A51        |             2 | Primary syphilis of other sites                                  | Sifilis primer pada tempat-tempat lain                                         |
# | A51        |             3 | Secondary syphilis of skin and mucous membranes                  | Sifilis sekunder pada kulit dan membran mukosa                                 |
# | A51        |             4 | Other secondary syphilis                                         | Sifilis sekunder lainnya                                                       |
# | A51        |             5 | Early syphilis, latent                                           | Sifilis dini, latent                                                           |
# | A51        |             9 | Early syphilis, unspecified                                      | Sifilis dini, tidak terspesifikasi                                             |
# | A52        |           nan | Late syphilis                                                    | Sifilis lanjut                                                                 |
# | A52        |             0 | Cardiovascular syphilis                                          | Sifilis kardiovascular                                                         |
# | A52        |             1 | Symptomatic neurosyphilis                                        | Neurosifilis simptomatik                                                       |
# ...
# | Y88        |             3 | Sequelae of surgical and medical procedures as the cause of      | Sekuele bedah dan prosedur-prosedur medik sebagai penyebab reaksi a             |
# | Y89        |           nan | Sequelae of other external causes                                | Sekuele penyebab-penyebab eksternal lain                                        |
# | Y89        |             0 | Sequelae of legal intervention                                   | Sekuele intervensi legal                                                        |
# | Y89        |             1 | Sequelae of war operations                                       | Sekuele operasi-operasi perang                                                  |
# | Y89        |             9 | Sequelae of unspecified external cause                           | Sekuele penyebab luar tak terspesifikasi                                        |
#
# ## GOL Z
# | Category   |   Subcategory | English_name                                                     | Indonesian_name                                                           |
# |:-----------|--------------:|:-----------------------------------------------------------------|:--------------------------------------------------------------------------|
# | Z00        |           nan | General examination and investigation of persons without com     | Pemeriksaan dan penyelidikan umum pada orang-orang tanpa keluhan a        |
# | Z01        |           nan | Other special examinations and investigations of persons with    | Pemeriksaan dan penyelidikan khusus lain pada orang-orang tanpa keluh     |
# | Z02        |           nan | Examination and encounter for administrative purposes            | Pemeriksaan dan pertemuan untuk tujuan administratif                      |
# | Z03        |           nan | Medical observation and evaluation for suspected diseases a      | Observasi dan evaluasi medis untuk penyaki-penyakit dan kondisi-kondis    |
# | Z04        |           nan | Examination and observation for other reasons                    | Pemeriksaan dan observasi untuk alasan-alasan lain                        |
# | Z08        |           nan | Follow-up examination after treatment for malignant neoplasm     | Pemeriksaan lanjutan sesudah pengobatan untuk neoplasma ganas             |
# | Z09        |           nan | Follow-up examination after treatment for conditions other-tha   | Pemeriksaan lanjutan sesudah pengobatan untuk kondisi-kondisi lain sel    |
# | Z10        |           nan | Routine general health check-up of defined subpopulation         | Pemeriksaan kesehatan umum rutin pada suatu subpopulasi                   |
# | Z11        |           nan | Special screening examination for infectious and parasitic dise  | Pemeriksaan skrining khusus untuk penyakit infeksi dan parasit            |
# | Z12        |           nan | Special screening examination for neoplasms                      | Pemeriksaan skrining khusus untuk neoplasma                               |
# | Z13        |           nan | Special screening examination for other disease and disorder     | Pemeriksaan skrining khusus untuk penyakit dan kelainan-kelainan lain     |
# | Z20        |           nan | Contact with and exposure to communicable diseases               | Kontak dengan dan terpapar oleh penyakit menular                          |
# | Z21        |           nan | Asymptomatic human immunodeficiency virus [HIV] infection        | Status infeksi asimptomatik virus yang melemahkan kekebalan tubuh ma      |
# | Z22        |           nan | Carrier of infectious disease                                    | Pembawa penyakit infeksi                                                  |
# | Z23        |           nan | Need for immunization against single bacterial diseases          | Perlu imunisasi untuk melawan penyakit bakteri tunggal                    |
# | Z24        |           nan | Need for immunization against certain single viral diseases      | Perlu imunisasi untuk melawan penyakit virus tunggal pasti                |
# | Z25        |           nan | Need for immunization against other single viral diseases        | Perlu imunisasi untuk melawan penyakit virus tunggal lain                 |
# | Z26        |           nan | Need for immunization against other single infectious diseases   | Perlu imunisasi untuk melawan penyakit infeksi tunggal lainnya            |
# | Z27        |           nan | Need for immunization against combinations of infectious dise    | Perlu imunisasi untuk melawan kombinasi-kombinasi penyakit infeksi        |
# | Z28        |           nan | Immunization not carried out                                     | Imunisasi tidak dilakukan                                                 |
# | Z29        |           nan | Need for other prophylactic measures                             | Perlu tindakan profilaktik lain                                           |
# | Z30        |           nan | Contraceptive management                                         | Manajemen kontraseptif                                                    |
# | Z31        |           nan | Procreative management                                           | Manajemen prokreatif                                                      |
# | Z32        |           nan | Pregnancy examination and test                                   | Pemeriksaan dan test kehamilan                                            |
# | Z33        |           nan | Pregnant state, incidental                                       | Status kehamilan, insidental                                              |
# | Z34        |           nan | Supervision of normal pregnancy                                  | Pengawasan kehamilan normal                                               |
# | Z35        |           nan | Supervision of high-risk pregnancy                               | Pengawasan kehamilan resiko tinggi                                        |
# | Z36        |           nan | Antenatal screening                                              | Skrining antenatal                                                        |
# | Z37        |           nan | Outcome of delivery                                              | Hasil dari kelahiran                                                      |
# | Z38        |           nan | Liveborn infants according to place of birth                     | Bayi lahir hidup menurut tempat kelahiran                                 |
# | Z39        |           nan | Postpartum care and examination                                  | Perawatan dan pemeriksaan pasca melahirkan                                |
# | Z40        |           nan | Prophylactic surgery                                             | Bedah profilaksi                                                          |
# | Z41        |           nan | Procedures for purposes other than remedying health state        | Prosedur-prosedur untuk tujuan selain perbaikan status kesehatan          |
# | Z42        |           nan | Follow-up care involving plastic surgery                         | Perawatan lanjut melibatkan bedah plastik                                 |
# | Z43        |           nan | Attention to artificial openings                                 | Perhatian pada lubang buatan                                              |
# | Z44        |           nan | Fitting and adjustment of external prosthetic device             | Penyesuaian dan pengaturan peralatan prostetik luar                       |
# | Z45        |           nan | Adjustment and management of implanted device                    | Pengaturan dan manajemen peralatan implan                                 |
# | Z46        |           nan | Fitting and adjustment of other devices                          | Penyesuaian dan pengaturan peralatan-peralatan lain                       |
# | Z47        |           nan | Other orthopaedic follow-up care                                 | Perawatan lanjut ortopedik lain                                           |
# | Z48        |           nan | Other surgical follow-up care                                    | Perawatan lanjut bedah lain                                               |
# | Z49        |           nan | Care involving dialysis                                          | Perawatan melibatkan dialisis                                             |
# | Z50        |           nan | Care involving use of rehabilitation procedures                  | Perawatan melibatkan penggunaan prosedur-prosedur rehabilitasi            |
# | Z51        |           nan | Other medical care                                               | Perawatan medik lain                                                      |
# | Z52        |           nan | Donors of organs and tissues                                     | Donor organ dan jaringan                                                  |
# | Z53        |           nan | Persons encountering health services for specific procedures,    | Orang mendatangi layanan kesehatan untuk prosedur spesifik, tidak dila    |
# | Z54        |           nan | Convalescence                                                    | Sembuh                                                                    |
# | Z55        |           nan | Problems related to education and literacy                       | Masalah-masalah terkait dengan pendidikan dan melek huruf (literasi)      |
# | Z56        |           nan | Problems related to employment and unemployment                  | Masalah-masalah terkait dengan pekerjaan dan pengangguran                 |
# | Z57        |           nan | Occupational exposure to risk-factors                            | Pekerjaan terpapar faktor resiko                                          |
# | Z58        |           nan | Problems related to physical environment                         | Masalah-masalah terkait dengan lingkungan fisik                           |
# | Z59        |           nan | Problems related to housing and economic circumstances           | Masalah-masalah terkait dengan perumahan dan kondisi ekonomi              |
# | Z60        |           nan | Problems related to social environment                           | Masalah-masalah terkait dengan lingkungan sosial                          |
# | Z61        |           nan | Problems related to negative life events in childhood            | Masalah-masalah terkait kejadian-kejadian hidup negatif pada masa kana    |
# | Z62        |           nan | Other problems related to upbringing                             | Masalah-masalah lain terkait dengan pengasuhan                            |
# | Z63        |           nan | Other problems related to primary support group, including fa    | Masalah-masalah lain terkait dengan dukungan utama grup, termasuk ko      |
# | Z64        |           nan | Problems related to certain psychosocial circumstances           | Masalah-masalah terkait dengan kondisi psikososial                        |
# | Z65        |           nan | Problems related to other psychosocial circumstances             | Masalah-masalah terkait dengan kondisi psikososial                        |
# | Z70        |           nan | Counselling related to sexual attitude, behaviour and orientati  | Konseling terkait dengan perilaku seksual, kebiasaan dan orientasi        |
# | Z71        |           nan | Persons encountering health services for other counselling an    | Orang mendatangi layanan kesehatan untuk konseling dan nasehat med        |
# | Z72        |           nan | Problems related to lifestyle                                    | Masalah-masalah terkait dengan gaya hidup                                 |
# | Z73        |           nan | Problems related to life-management difficulty                   | Masalah-masalah terkait dengan kesulitan manajemen hidup                  |
# | Z74        |           nan | Problems related to care-provider dependency                     | Masalah-masalah terkait dengan ketergantungan terhadap penyedia pera      |
# | Z75        |           nan | Problems related to medical facilities and other health care     | Masalah-masalah terkait dengan fasilitas medik dan pelayanan kesehata     |
# | Z76        |           nan | Persons encountering health services in other circumstances      | Orang mendatangi layanan kesehatan dalam kondisi lain                     |
# | Z80        |           nan | Family history of malignant neoplasm                             | Riwayat keluarga menderita neoplasma ganas                                |
# | Z81        |           nan | Family history of mental and behavioural disorders               | Riwayat keluarga menderita kelainan-kelainan mental dan tingkah laku      |
# | Z82        |           nan | Family history of certain disabilities and chronic diseases lead | Riwayat keluarga menderita kecacatan tertentu dan penyakit kronis yang    |
# | Z83        |           nan | Family history of other specific disorders                       | Riwayat keluarga menderita kelainan-kelainan spesifik lain                |
# | Z84        |           nan | Family history of other conditions                               | Riwayat keluarga dengan kondisi-kondisi lain                              |
# | Z85        |           nan | Personal history of malignant neoplasm                           | Riwayat pribadi menderita neoplasma ganas                                 |
# | Z86        |           nan | Personal history of certain other diseases                       | Riwayat pribadi menderita penyakit-penyakit tertentu lain                 |
# | Z87        |           nan | Personal history of other diseases and conditions                | Riwayat pribadi menderita kondisi-kondisi dan penyekit-penyakit lain      |
# | Z88        |            21 | Personal history of allergy to drugs, medicaments and biologic   | Riwayat pribadi menderita alergi terhadap obat, medikamentosa dan subs    |
# | Z89        |           nan | Acquired absence of limb                                         | Tidak mempunyai alat gerak dapatan                                        |
# | Z90        |           nan | Acquired absence of organs not elsewhere classified              | Tidak mempunyai organ-organ dapatan tidak terklasifikasi ditempat lain    |
# | Z91        |           nan | Personal history of risk-factors, not elsewhere classified       | Riwayat pribadi terkena faktor resiko, tidak terklasifikasi ditempat lain |
# | Z92        |           nan | Personal history of medical treatment                            | Riwayat pribadi menjalani pengobatan medis                                |
# | Z93        |           nan | Artificial opening status                                        | Status lubang buatan                                                      |
# | Z94        |           nan | Transplanted organ and tissue status                             | Status transplantasi organ dan jaringan                                   |
# | Z95        |           nan | Presence of cardiac and vascular implants and grafts             | Adanya implan dan graft pada jantung dan pembuluh darah                   |
# | Z96        |           nan | Presence of other functional implants                            | Adanya implan-implan fungsional lain                                      |
# | Z97        |           nan | Presence of other devices                                        | Adanya peralatan-peralatan lain                                           |
# | Z98        |           nan | Other postsurgical states                                        | Keadaan pasca bedah lainnya                                               |
# | Z99        |           nan | Dependence on enabling machines and devices, not elsewhe         | Ketergantungan pada mesin dan peralatan, tidak terklasifikasi             |

# %% [markdown]
# # Split Reference

# %%
# Load and splitting files
loader = DirectoryLoader('/content', glob="*.md")
data = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size = 300, chunk_overlap = 100)
all_splits = text_splitter.split_documents(data)

all_splits[100]
# Out:
# Document(metadata={'source': '/content/output.md'}, page_content='Gonokokus pada saluran genital-kemih bawah d A54 2 Gonococcal pelviperitonitis and other gonococcal genitou rinar Peritonitis panggul dan infeksi genital-kemih lain yang d A54 3 Gonococcal infection of eye Infeksi Gonokokus pada mata A54 4 Gonococcal infection of musculoskeletal system Infeksi')

# %% [markdown]
# # Store Reference

# %%
# Storing embeddings for text retrieval
vectorstore = Chroma.from_documents(documents=all_splits, embedding=OpenAIEmbeddings())
retriever = vectorstore.as_retriever()
# Out:
# <ipython-input-6-0c8347fd17e0>:2: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   vectorstore = Chroma.from_documents(documents=all_splits, embedding=OpenAIEmbeddings())

# %%
# Retrieving context from the vectorstore
rag_prompt = hub.pull("rlm/rag-prompt")
# Out:
# /usr/local/lib/python3.10/dist-packages/langsmith/client.py:323: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(

# %%
# Define ChatGPT model
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
# Out:
# <ipython-input-8-fc41f5ac53ab>:2: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
# Define RAG chain setup
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | rag_prompt
    | llm
)

# %%
# Try invoke the chain
rag_chain.invoke("What is the ICD code for meningitis")
# Out:
# AIMessage(content='The ICD code for meningitis is G00.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 475, 'total_tokens': 486, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-cce817f8-b87e-4354-9984-2debd8665127-0')

# %%
# Check reference pulled out
question = "What is the ICD code for meningitis"
docs = vectorstore.similarity_search(question)
len(docs)
# Out:
# 4

# %%
# Check reference pulled out
docs
# Out:
# [Document(metadata={'source': '/content/output.md'}, page_content='Category Subcategory English_name Indonesian_name G00 0 Hemophilus meningitis Meningitis hemofilus G00 1 Pneumococcal meningitis Meningitis pneumokokkus G00 2 Streptococcal meningitis Meningitis streptokokkus G00 3 Staphylococcal meningitis Meningitis stafilokokkus G00 8 Other bacterial meningitis'),
#  Document(metadata={'source': '/content/output.md'}, page_content='infection Infeksi meningokokus A39 0 Meningococcal meningitis Meningitis meningokokus A39 1 Waterhouse-Friderichsen syndrome Sindrom Waterhouse-Friderichsen A39 2 Acute meningococcemia Meningokoksemia akut A39 3 Chronic meningococcemia Meningokoksemia kronik A39 4 Meningococcemia, unspecified'),
#  Document(metadata={'source': '/content/output.md'}, page_content='G00 3 Staphylococcal meningitis Meningitis stafilokokkus G00 8 Other bacterial meningitis Meningitis bakterial lainnya G00 9 Bacterial meningitis, unspecified Meningitis bakterial, tidak terspesifikasi G03 nan Meningitis due to other and unspecified causes Meningitis yang diakibatkan oleh'),
#  Document(metadata={'source': '/content/output.md'}, page_content='A39 8 Other meningococcal infections Infeksi meningokokus lainnya A39 9 Meningococcal infection, unspecified Infeksi meningokokus, tidak terspesifikasi A40 nan Streptococcal septicemia Septikemia yang disebabkan oleh streptokokus A40 0 Septicemia due to streptococcus, group A Septikemia yang')]

# %% [markdown]
# # Generate Response

# %%
# Define response pipeline
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

from langchain.chains import RetrievalQA

qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=vectorstore.as_retriever()
)

# %% [markdown]
# ## Simple Prompt

# %%
# Try with simple prompt
question = "What is the ICD code for meningitis"
result = qa_chain({"query": question})
result["result"]
# Out:
# <ipython-input-14-d5b7f0fa61cb>:3: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = qa_chain({"query": question})
# 'The ICD code for meningitis is G00.'

# %% [markdown]
# ## Template Prompt

# %%
# Try with template prompt in English
question = input("Tell us the symptoms: ")

PROMPT_TEMPLATE = """
Answer this question with context provided below. If the question cannot be answered using the information provided answer with "I don't know".

---

{context}

---
Give ICD code recommendation based on the question in english and indonesia according to the context above: {question}, DO NOT CREATE OR ASSUME NEW CODE! STRICLY USE THE CODE PROVIDED!

---

Generate response with this template:

ICD Code: <ICD Code>
Description (English): <Description>
Deskripsi (Indonesia): <Deskripsi>

"""

# Prepare the DB.
embedding_function = OpenAIEmbeddings()

# Search the DB.
results = vectorstore.similarity_search_with_relevance_scores(question, k=3)
if len(results) == 0 or results[0][1] < 0.6:
    print(f"Unable to find matching results.")

context_text = "\n\n---\n\n".join([doc.page_content for doc, _score in results])
prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
prompt = prompt_template.format(context=context_text, question=question)
# print(prompt)

model = ChatOpenAI()
response_text = model.predict(prompt)

sources = [doc.metadata.get("source", None) for doc, _score in results]
formatted_response = f"Response: {response_text}\nSources: {sources}"
print(formatted_response)
# Out:
# Tell us the symptoms: i have a fever for almost 2 days
# Response: ICD Code: R50 1
# Description (English): Persistent fever
# Deskripsi (Indonesia): Demam menetap
# Sources: ['/content/output.md', '/content/output.md', '/content/output.md']

# %%
# Try with template prompt in Indonesia
question = input("Deskripsikan gejala yang dirasakan: ")

PROMPT_TEMPLATE = """
Answer this question with context provided below. If the question cannot be answered using the information provided answer with "I don't know".

---

{context}

---
Give ICD code recommendation based on the question in english and indonesia according to the context above: {question}, DO NOT CREATE OR ASSUME NEW CODE! STRICLY USE THE CODE PROVIDED!

---

Generate response with this template:

ICD Code: <ICD Code>
Description (English): <Description>
Deskripsi (Indonesia): <Deskripsi>

"""

# Prepare the DB.
embedding_function = OpenAIEmbeddings()

# Search the DB.
results = vectorstore.similarity_search_with_relevance_scores(question, k=3)
if len(results) == 0 or results[0][1] < 0.6:
    print(f"Unable to find matching results.")

context_text = "\n\n---\n\n".join([doc.page_content for doc, _score in results])
prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
prompt = prompt_template.format(context=context_text, question=question)
# print(prompt)

model = ChatOpenAI()
response_text = model.predict(prompt)

sources = [doc.metadata.get("source", None) for doc, _score in results]
formatted_response = f"Response: {response_text}\nSources: {sources}"
print(formatted_response)
# Out:
# Deskripsikan gejala yang dirasakan: saya merasakan demam terus menerus selama 2 hari
# Response: ICD Code: R50 9
# Description (English): Fever, unspecified
# Deskripsi (Indonesia): Demam, tidak terspesifikasi
# Sources: ['/content/output.md', '/content/output.md', '/content/output.md']
